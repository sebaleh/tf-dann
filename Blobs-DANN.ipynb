# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cPickle as pkl
from sklearn.datasets import make_moons, make_blobs
from sklearn.decomposition import PCA

from flip_gradient import flip_gradient
from utils import *

# %% [markdown]
# Make a blob dataset. Dark vs. light colors distinguish domain and redish vs bluish colors distinguish class.

# %%
Xs, ys = make_blobs(300, centers=[[0, 0], [0, 1]], cluster_std=0.2)
Xt, yt = make_blobs(300, centers=[[1, -1], [1, 0]], cluster_std=0.2)

plt.scatter(Xs[:,0], Xs[:,1], c=ys, alpha=0.4)
plt.scatter(Xt[:,0], Xt[:,1], c=yt, cmap='cool', alpha=0.4)

# %%
batch_size = 10

def build_model(shallow_domain_classifier=True):
    X = tf.placeholder(tf.float32, [None, 2], name='X') # Input data
    Y_ind = tf.placeholder(tf.int32, [None], name='Y_ind')  # Class index
    D_ind = tf.placeholder(tf.int32, [None], name='D_ind')  # Domain index
    train = tf.placeholder(tf.bool, [], name='train')       # Switch for routing data to class predictor
    l = tf.placeholder(tf.float32, [], name='l')        # Gradient reversal scaler

    Y = tf.one_hot(Y_ind, 2)
    D = tf.one_hot(D_ind, 2)

    # Feature extractor - single layer
    W0 = weight_variable([2, 15])
    b0 = bias_variable([15])
    F = tf.nn.relu(tf.matmul(X, W0) + b0, name='feature')

    # Label predictor - single layer
    f = tf.cond(train, lambda: tf.slice(F, [0, 0], [batch_size / 2, -1]), lambda: F)
    y = tf.cond(train, lambda: tf.slice(Y, [0, 0], [batch_size / 2, -1]), lambda: Y)

    W1 = weight_variable([15, 2])
    b1 = bias_variable([2])
    p_logit = tf.matmul(f, W1) + b1
    p = tf.nn.softmax(p_logit)
    p_loss = tf.nn.softmax_cross_entropy_with_logits(logits=p_logit,labels= y)

    # Domain predictor - shallow
    f_ = flip_gradient(F, l)

    if shallow_domain_classifier:
        W2 = weight_variable([15, 2])
        b2 = bias_variable([2])
        d_logit = tf.matmul(f_, W2) + b2
        d = tf.nn.softmax(d_logit)
        d_loss = tf.nn.softmax_cross_entropy_with_logits(logits=d_logit,labels= D)

    else:
        W2 = weight_variable([15, 8])
        b2 = bias_variable([8])
        h2 = tf.nn.relu(tf.matmul(f_, W2) + b2)

        W3 = weight_variable([8, 2])
        b3 = bias_variable([2])
        d_logit = tf.matmul(h2, W3) + b3
        d = tf.nn.softmax(d_logit)
        d_loss = tf.nn.softmax_cross_entropy_with_logits(logits=d_logit,labels= D)


    # Optimization
    pred_loss = tf.reduce_sum(p_loss, name='pred_loss')
    domain_loss = tf.reduce_sum(d_loss, name='domain_loss')
    total_loss = tf.add(pred_loss, domain_loss, name='total_loss')

    pred_train_op = tf.train.AdamOptimizer(0.01).minimize(pred_loss, name='pred_train_op')
    domain_train_op = tf.train.AdamOptimizer(0.01).minimize(domain_loss, name='domain_train_op')
    dann_train_op = tf.train.AdamOptimizer(0.01).minimize(total_loss, name='dann_train_op')

    # Evaluation
    p_acc = tf.reduce_mean(tf.cast(tf.equal(tf.arg_max(y, 1), tf.arg_max(p, 1)), tf.float32), name='p_acc')
    d_acc = tf.reduce_mean(tf.cast(tf.equal(tf.arg_max(D, 1), tf.arg_max(d, 1)), tf.float32), name='d_acc')

# %%
build_model()
sess = tf.InteractiveSession()

def train_and_evaluate(sess, train_op_name, train_loss_name, grad_scale=None, num_batches=10000, verbose=True):
    # Create batch builders
    S_batches = batch_generator([Xs, ys], batch_size / 2)
    T_batches = batch_generator([Xt, yt], batch_size / 2)
    
    # Get output tensors and train op
    d_acc = sess.graph.get_tensor_by_name('d_acc:0')
    p_acc = sess.graph.get_tensor_by_name('p_acc:0')
    train_loss = sess.graph.get_tensor_by_name(train_loss_name + ':0')
    train_op = sess.graph.get_operation_by_name(train_op_name)
    
    sess.run(tf.initialize_all_variables())
    for i in range(num_batches):

        # If no grad_scale, use a schedule
        if grad_scale is None:
            p = float(i) / num_batches
            lp = 2. / (1. + np.exp(-10. * p)) - 1
        else:
            lp = grad_scale

        X0, y0 = S_batches.next()
        X1, y1 = T_batches.next()
        Xb = np.vstack([X0, X1])
        yb = np.hstack([y0, y1])
        D_labels = np.hstack([np.zeros(batch_size / 2, dtype=np.int32),
                              np.ones(batch_size / 2, dtype=np.int32)])

        _, loss, da, pa = sess.run([train_op, train_loss, d_acc, p_acc],
                                   feed_dict={'X:0': Xb, 'Y_ind:0': yb, 'D_ind:0': D_labels,
                                              'train:0': True, 'l:0': lp})

        if verbose and i % 200 == 0:
            print 'loss: %f, domain accuracy: %f, class accuracy: %f' % (loss, da, pa)

            
    # Get final accuracies on whole dataset
    das, pas = sess.run([d_acc, p_acc], feed_dict={'X:0': Xs, 'Y_ind:0': ys, 
                            'D_ind:0': np.zeros(Xs.shape[0], dtype=np.int32), 'train:0': False, 'l:0': 1.0})
    dat, pat = sess.run([d_acc, p_acc], feed_dict={'X:0': Xt, 'Y_ind:0': yt,
                            'D_ind:0': np.ones(Xt.shape[0], dtype=np.int32), 'train:0': False, 'l:0': 1.0})

    print 'Source domain: ', das
    print 'Source class: ', pas
    print 'Target domain: ', dat
    print 'Target class: ', pat


def extract_and_plot_pca_feats(sess, feat_tensor_name='feature'):
    F = sess.graph.get_tensor_by_name(feat_tensor_name + ':0')
    emb_s = sess.run(F, feed_dict={'X:0': Xs})
    emb_t = sess.run(F, feed_dict={'X:0': Xt})
    emb_all = np.vstack([emb_s, emb_t])

    pca = PCA(n_components=2)
    pca_emb = pca.fit_transform(emb_all)

    num = pca_emb.shape[0] / 2
    plt.scatter(pca_emb[:num,0], pca_emb[:num,1], c=ys, alpha=0.4)
    plt.scatter(pca_emb[num:,0], pca_emb[num:,1], c=yt, cmap='cool', alpha=0.4)

# %% [markdown]
# #### Domain classification
#
# Setting `grad_scale=-1.0` effectively turns off the gradient reversal. Training just the domain classifier creates representation that collapses classes.

# %%
train_and_evaluate(sess, 'domain_train_op', 'domain_loss', grad_scale=-2.0, verbose=True)
extract_and_plot_pca_feats(sess)
# Out:
# WARNING:tensorflow:From <ipython-input-4-32e74dbce75b>:15: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# loss: 11.114985, domain accuracy: 0.500000, class accuracy: 0.125000
# loss: 0.401423, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 2.749506, domain accuracy: 0.937500, class accuracy: 0.375000
# loss: 1.105338, domain accuracy: 0.937500, class accuracy: 0.375000
# loss: 0.024619, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 0.004991, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.004485, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.010959, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.006153, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.017243, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.005823, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.109194, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.006836, domain accuracy: 1.000000, class accuracy: 0.125000
# loss: 0.007275, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.002949, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.050505, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.549273, domain accuracy: 1.000000, class accuracy: 0.750000
# loss: 0.008044, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 0.014659, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 1.640379, domain accuracy: 0.937500, class accuracy: 0.500000
# loss: 0.000410, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.003443, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.005781, domain accuracy: 1.000000, class accuracy: 0.750000
# loss: 0.003779, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.064446, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.001266, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.004590, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.000902, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000183, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.790452, domain accuracy: 0.937500, class accuracy: 0.125000
# loss: 0.000788, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000432, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 0.373991, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000319, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.026890, domain accuracy: 1.000000, class accuracy: 0.625000
# loss: 0.003541, domain accuracy: 1.000000, class accuracy: 0.125000
# loss: 0.000245, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.006992, domain accuracy: 1.000000, class accuracy: 0.750000
# loss: 0.082787, domain accuracy: 1.000000, class accuracy: 0.125000
# loss: 0.458750, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 0.000173, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.000254, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000069, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.004690, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000925, domain accuracy: 1.000000, class accuracy: 0.250000
# loss: 0.006656, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000390, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000667, domain accuracy: 1.000000, class accuracy: 0.500000
# loss: 0.000494, domain accuracy: 1.000000, class accuracy: 0.375000
# loss: 0.000023, domain accuracy: 1.000000, class accuracy: 0.625000
# Source domain:  0.996667
# Source class:  0.436667
# Target domain:  0.996667
# Target class:  0.496667

# %% [markdown]
# #### Label classification
#
# Training label prediction in the source domain results in poor adapatation to the target. (1) The representation separates the classes in the source domain, but fails to separate the classes of the target domain. (2) The representation shows significant separation of classes.

# %%
train_and_evaluate(sess, 'pred_train_op', 'pred_loss', verbose=True)
extract_and_plot_pca_feats(sess)
# Out:
# WARNING:tensorflow:From <ipython-input-4-32e74dbce75b>:15: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# loss: 5.436769, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.537412, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.596088, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.181371, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.595083, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001252, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.237896, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.045462, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 1.475356, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.001742, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.002150, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.010454, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.901552, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.001196, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.002149, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001471, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.003264, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001283, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.040769, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.113900, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.008713, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.460638, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.003076, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.797543, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.004436, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000639, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.036853, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000540, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000863, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.006655, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.004291, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.014735, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000257, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.002427, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.648724, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000373, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001560, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.004349, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.864143, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.001551, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.262267, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.004996, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001742, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.706846, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.925461, domain accuracy: 0.500000, class accuracy: 0.875000
# loss: 0.001685, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.006327, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.015315, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.001056, domain accuracy: 0.500000, class accuracy: 1.000000
# loss: 0.000652, domain accuracy: 0.500000, class accuracy: 1.000000
# Source domain:  0.0
# Source class:  0.993333
# Target domain:  1.0
# Target class:  0.506667

# %% [markdown]
# #### Domain adaptation
#
# Training with domain adversarial loss results in much better transfer to the target. The domains can usually still be distinguished in repeated experiments.

# %%
train_and_evaluate(sess, 'dann_train_op', 'total_loss', verbose=True)
extract_and_plot_pca_feats(sess)
# Out:
# WARNING:tensorflow:From <ipython-input-4-32e74dbce75b>:15: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# loss: 16.545326, domain accuracy: 0.500000, class accuracy: 0.750000
# loss: 1.091700, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.426606, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 30.221004, domain accuracy: 0.437500, class accuracy: 1.000000
# loss: 1.793394, domain accuracy: 0.937500, class accuracy: 1.000000
# loss: 0.007353, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.022632, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 1.330990, domain accuracy: 1.000000, class accuracy: 0.875000
# loss: 0.624659, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 2.342996, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.085968, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.261828, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.644928, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.147981, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 1.214492, domain accuracy: 0.937500, class accuracy: 1.000000
# loss: 1.606191, domain accuracy: 1.000000, class accuracy: 0.875000
# loss: 0.191619, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 1.361841, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.066808, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 26.991474, domain accuracy: 0.312500, class accuracy: 1.000000
# loss: 0.279087, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.030993, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.495405, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.112494, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.382545, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.009195, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.003511, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 1.353438, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.004521, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.001581, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.005160, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.324440, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 1.195394, domain accuracy: 0.937500, class accuracy: 1.000000
# loss: 0.000264, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.154447, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.001291, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.215480, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.001598, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.017862, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.000373, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.184995, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.006918, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.001124, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.485364, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.002000, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.035118, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.015205, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.006601, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.246575, domain accuracy: 1.000000, class accuracy: 1.000000
# loss: 0.047172, domain accuracy: 1.000000, class accuracy: 1.000000
# Source domain:  0.993333
# Source class:  0.993333
# Target domain:  0.996667
# Target class:  0.55

# %% [markdown]
# #### Domain adaptation - deeper domain classifier
#
# Using a domain classifier that is deeper seems to more reliably collapse the domains on this problem in repeated experiments.

# %%
sess.close()
tf.reset_default_graph()
build_model(False)
sess = tf.InteractiveSession()

train_and_evaluate(sess, 'dann_train_op', 'total_loss', verbose=False)
extract_and_plot_pca_feats(sess)
# Out:
# WARNING:tensorflow:From <ipython-input-4-32e74dbce75b>:15: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Source domain:  1.0
# Source class:  1.0
# Target domain:  0.0
# Target class:  0.5
